# %%
# %matplotlib inline
from fastai.basics import *

# %%
n = 100

# %%
x = torch.ones(n, 2)
x[:, 0].uniform_(-1, 1)

x[:5, :]
# Out:
# tensor([[ 0.1973,  1.0000],
#         [ 0.5540,  1.0000],
#         [-0.2527,  1.0000],
#         [ 0.0178,  1.0000],
#         [-0.4650,  1.0000]])

# %%
a = tensor(3., 2)

a
# Out:
# tensor([3., 2.])

# %%
y = x@a + torch.rand(n)

# %%
torch.rand?

# %%
plt.scatter(x[:, 0], y);

# %%
def mse(y_hat, y): return ((y_hat - y)**2).mean()

# %%
a = tensor(-1, 1.)

# %%
y_hat = x@a

# %%
mse(y_hat, y)
# Out:
# tensor(5.4226)

# %%
plt.scatter(x[:, 0], y);
plt.scatter(x[:, 0], y_hat);

# %%
a = nn.Parameter(a)

# %%
a
# Out:
# Parameter containing:
# tensor([-1.,  1.], requires_grad=True)

# %%
def update():
    y_hat = x@a
    loss = mse(y_hat, y)
    if t % 10 == 0: print(loss)
    loss.backward()
    with torch.no_grad():
        a.sub_(lr * a.grad)
        a.grad.zero_()

# %%
lr = .1
for t in range(500):
    update()
# Out:
# tensor(0.0957, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)
# tensor(0.0956, grad_fn=<MeanBackward1>)

# %%
plt.scatter(x[:, 0], y);
plt.scatter(x[:, 0], x@a);

# %%
from matplotlib import animation, rc

# %%
rc('animation', html='jshtml')

# %%
a = nn.Parameter(tensor(-1, 1.))

# %%
fig = plt.figure()
plt.scatter(x[:, 0], y, c='orange')
line, = plt.plot(x[:, 0], x@a)

# %%
plt.close()

# %%
def animate(i):
    update()
    line.set_ydata(x@a)
    return line,

# %%
animation.FuncAnimation(fig, animate, np.arange(0, 100), interval=5)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgd4a1cfe8186746d78128145057658ccc">
#     <br>
#     <input id="_anim_sliderd4a1cfe8186746d78128145057658ccc" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animd4a1cfe8186746d78128145057658ccc.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animd4a1cfe8186746d78128145057658ccc.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animd4a1cfe8186746d78128145057658ccc.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animd4a1cfe8186746d78128145057658ccc.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animd4a1cfe8186746d78128145057658ccc.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animd4a1cfe8186746d78128145057658ccc.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animd4a1cfe8186746d78128145057658ccc.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animd4a1cfe8186746d78128145057658ccc.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animd4a1cfe8186746d78128145057658ccc.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animd4a1cfe8186746d78128145057658ccc.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectd4a1cfe8186746d78128145057658ccc" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd4a1cfe8186746d78128145057658ccc";
#     var slider_id = "_anim_sliderd4a1cfe8186746d78128145057658ccc";
#     var loop_select_id = "_anim_loop_selectd4a1cfe8186746d78128145057658ccc";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAAIABJREFUeJzt3X90VNXd7/HPJCHU+BtJChElCUFU\
# MNgSCDy9pYilKEVbr1FRqvirsdXeUntr7bNoa/VCsb39ZSvqyrJanpZCW+uVXrTYq6h9alWc8uMp\
# orZKgoKogYhaFEKSff8YZ8iPc86cmTkzZ/bM+7WWK+TMmTPfNYnzzd77e747YowxAgDAMiVhBwAA\
# QDpIYAAAK5HAAABWIoEBAKxEAgMAWIkEBgCwEgkMAGAlEhgAwEokMACAlUhgAAArkcAAAFYigQEA\
# rEQCAwBYiQQGALASCQwAYCUSGADASiQwAICVSGAAACuRwAAAViKBAQCsRAIDAFiJBAYAsBIJDABg\
# JRIYAMBKJDAAgJVIYAAAK5HAAABWIoEBAKxEAgMAWIkEBgCwEgkMAGAlEhgAwEokMACAlUhgAAAr\
# lYUdQLYMHz5cNTU1YYcBAFZpb2/X7t27ww7DF2sS2N69e3X11Vdry5YtikQiuueeezRt2jTX82tq\
# ahSNRnMYIQDYr7GxMewQfLMmgS1cuFBnnXWW7rvvPnV1dem9994LOyQAQIisSGDvvPOO/vznP+sX\
# v/iFJKm8vFzl5eXhBgUACJUVRRzbtm1TZWWlrrjiCn3kIx/R1VdfrX379oUdFgAgRFYksO7ubm3Y\
# sEFf/OIXtXHjRh1++OG69dZbB53X2tqqxsZGNTY2qqOjI4RIAQC5YkUCGzVqlEaNGqWmpiZJUnNz\
# szZs2DDovJaWFkWjUUWjUVVWVuY6TABADlmRwEaMGKETTjhBL774oiTp0Ucf1amnnhpyVACQB9pW\
# SA/USL8uiX1tWxF2RDljRRGHJP3sZz/T/Pnz1dXVpbq6Ot17771hhwQA4WpbIa1vkXo+qMp+b3vs\
# e0mqnR9eXDliTQI7/fTTua8LAPravOhQ8orreS92vAgSmBVTiAAAB++9ktrxAkMCAwBbVZyY2vEC\
# QwIDAFtNXCKVVvQ/VloRO14ESGAAYKva+dKUVqlitKRI7OuU1qJY/5IsKuIAADionV80CWsgRmAA\
# ACuRwAAAViKBAQCsRAIDgFwq4tZPQaOIAwBypchbPwWNERgA5IpX6yekjAQGALmSrdZPRTotSQID\
# gFxJt/WTV4KKT0u+t12SOTQtWQRJjAQGALmSTuunZAmqiKclSWAAkCvptH5KlqCKuCM9VYgAkEup\
# tn5KlqAqTvxgdDZAEXSkZwQGAPks2bpZEXekJ4EBQD5LlqCKuCM9U4gAkM/iiWjzoti0YcWJseTV\
# N0EVaUd6EhgA5LsiTVDJMIUIAE6K9OZgm1gzAqupqdGRRx6p0tJSlZWVKRqNhh0SgELl1LPwqc9J\
# 0YVS422MhvKENQlMkh577DENHz487DAAFDqne68k6eAemu/mEaYQAWAgr5uAi6TLhQ2sSWCRSESf\
# +tSnNGnSJLW2toYdDoBCluwm4CLocmEDa6YQn3zySVVXV+vNN9/UrFmzdPLJJ2v69On9zmltbU0k\
# t46OjjDCBFAIJi7pvwY2UBF0ubCBNSOw6upqSVJVVZXOO+88rV+/ftA5LS0tikajikajqqyszHWI\
# AApF/Obg8uMGPxYZUhRdLmxgRQLbt2+f3n333cS///SnP2nChAkhRwWgoNXOlybdJpWU9z8eiYQT\
# DwaxYgrxjTfe0HnnnSdJ6u7u1iWXXKKzzjor5KgAFLzNi6Terv7Hertix6lCDJ0VCayurk6bN28O\
# OwwAxca1E/z22M3Nbq2dkBNWTCECQChcizUiRbkDcr4hgQGAG6dO8IpIMv0PcW9YKEhgAODGaauS\
# gckrjnvDco4EBqDwBNmIt3a+9Nl26ZLe2NeK0c7ncW9YzpHAABSWeCPebK1RZbo

# %%
a
# Out:
# Parameter containing:
# tensor([3.0222, 2.5321], requires_grad=True)
